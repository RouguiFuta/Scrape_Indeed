# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
sns.set_context('poster')
import requests
import bs4
import time

# %%
#request web page and parse with Beautiful Soup
req = requests.get('https://www.indeed.com/jobs?q=web+developer&l=Boston%2C+MA')
page = req.text
soup = bs4.BeautifulSoup(page,'html.parser')

#check that the parser worked
print(soup.title)
print(soup.prettify()[:1000])
# Out:
# <title>Web Developer Jobs, Employment in Boston, MA | Indeed.com</title>
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
#   <script src="/s/f42152d/en_US.js" type="text/javascript">
#   </script>
#   <link href="/s/ecdfb5e/jobsearch_all.css" rel="stylesheet" type="text/css"/>
#   <link href="http://rss.indeed.com/rss?q=web+developer&amp;l=Boston%2C+MA" rel="alternate" title="Web Developer Jobs, Employment in Boston, MA" type="application/rss+xml"/>
#   <link href="/m/jobs?q=web+developer&amp;l=Boston%2C+MA" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <link href="/m/jobs?q=web+developer&amp;l=Boston%2C+MA" media="handheld" rel="alternate"/>
#   <script type="text/javascript">
#    if (typeof window['closureReadyCallbacks'] == 'undefined') {
#         window['closureReadyCallbacks'] = [];
#     }
#
#     function call_when_jsall_loaded(cb) {
#         if (window['closureReady']) {
#             cb();
#         } else {
#             window['closureReadyCallbacks'].push(cb);
#         }
#     }
#   </script>
#   <m

# %%
#getting job titles

def extract_job_title_from_result(soup): 
    jobs = []
    for div in soup.find_all(name='div', attrs={'class':'row'}):
        for a in div.find_all(name='a', attrs={'data-tn-element':'jobTitle'}):
            jobs.append(a['title'])
    return(jobs)

extract_job_title_from_result(soup)
# Out:
# ['Front End Developer',
#  'Front-end Web Developer (E-Commerce)',
#  'Transportation Designer/Engineer',
#  'Frontend Software Developer (Javascript / Ember JS)',
#  'ServiceNow Admin',
#  'Web / Front End Developer',
#  'Junior Back-End Development Position (remote)',
#  'Front-End Developer',
#  'Front End Developer',
#  'Full Stack Web Developer',
#  'Junior Developer - Sheprd',
#  'Full Stack Web Developer',
#  'Front-end Developer',
#  'Lead Full Stack Web Developer',
#  'Senior Web Developer']

# %%
#getting company names

def extract_company_from_result(soup): 
    companies = []
    for div in soup.find_all(name='div', attrs={'class':'row'}):
        company = div.find_all(name='span', attrs={'class':'company'})
        if len(company) > 0:
            for b in company:
                companies.append(b.text.strip())
        else:
            sec_try = div.find_all(name='span', attrs={'class':'result-link-source'})
            for span in sec_try:
                companies.append(span.text.strip())
    return(companies)
 
extract_company_from_result(soup)
# Out:
# ['RWS Group',
#  'Digital Management, LLC',
#  'Nitsch Engineering, Inc.',
#  'Humanyze',
#  'Netpro System',
#  'FEN Learning / StoryArc Media',
#  'Kuvio Creative, LLC.',
#  'Coresecure, Inc.',
#  'Abt Associates',
#  'Boston',
#  'InMotion Ventures',
#  'Artaic',
#  'CareDash',
#  'Liberty Mutual',
#  'Pluralsight']

# %%
#getting location

def extract_location_from_result(soup): 
    locations = []
    spans = soup.find_all('span', attrs={'class': 'location'})
    for span in spans:
        locations.append(span.text)
    return(locations)

extract_location_from_result(soup)
# Out:
# ['Boston, MA',
#  'Burlington, MA',
#  'Boston, MA 02108',
#  'Boston, MA 02108 (Back Bay-Beacon Hill area)',
#  'Boston, MA',
#  'Boston, MA',
#  'Boston, MA',
#  'Cambridge, MA 02142 (East Cambridge area)',
#  'Cambridge, MA 02138 (West Cambridge area)',
#  'Boston, MA 02113 (Central area)',
#  'Boston, MA',
#  'Boston, MA',
#  'Cambridge, MA',
#  'Boston, MA',
#  'Boston, MA']

# %%
def extract_salary_from_result(soup): 
    salaries = []
    for div in soup.find_all(name='div', attrs={'class':'row'}):
        try:
            salaries.append(div.find('nobr').text)
        except:
            try:
                div_two = div.find(name='div', attrs={'class':'sjcl'})
                div_three = div_two.find('div')
                salary = div_three.find_all(name='span', attrs={'class':'no-wrap'})
                salaries.append(salary.text)
            except:
                salaries.append('Nothing_found')
    return(salaries)

extract_salary_from_result(soup)
# Out:
# ['Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found']

# %%
columns = ['job_title', 'company_name', 'location', 'salary']
sample_df = pd.DataFrame(columns = columns)

# %%
#scraping code:

#getting data from multiple pages
for start in range(0,3):
    page = requests.get('https://www.indeed.com/jobs?q=web+developer&l=Boston%2C+MA'+ '&start='+ str(start))
    time.sleep(1)  #ensuring at least 1 second between page grabs

#populating data frame
    for div in soup.find_all(name='div', attrs={'class':'row'}): 
#specifying row num for index of job posting in dataframe
        num = (len(sample_df) + 1) 
#creating an empty list to hold the data for each posting
        job_post = [] 
#append city name
#job_post.append(city) 
    
#grabbing job title
        for a in div.find_all(name='a', attrs={'data-tn-element':'jobTitle'}):
            job_post.append(a['title']) 
#grabbing company name
            company = div.find_all(name='span', attrs={'class':'company'}) 
            if len(company) > 0: 
                for b in company:
                    job_post.append(b.text.strip()) 
            else: 
                sec_try = div.find_all(name='span', attrs={'class':'result-link-source'})
                for span in sec_try:
                    job_post.append(span.text) 
#grabbing location name
            c = div.findAll('span', attrs={'class': 'location'}) 
            for span in c: 
                job_post.append(span.text) 
#grabbing salary
                try:
                    job_post.append(div.find('nobr').text) 
                except:
                    try:
                        div_two = div.find(name='div', attrs={'class':'sjcl'})
                        div_three = div_two.find('div')
                        salary = div_three.find_all(name='span', attrs={'class':'no-wrap'})
                        salaries.append(salary.text.strip())
                    except:
                        job_post.append('Nothing_found') 

#appending list of job post info to dataframe at index num
        sample_df.loc[num] = job_post

sample_df

#saving sample_df as a local csv file — define your own local path to save contents 
#sample_df.to_csv(“[filepath].csv”, encoding=’utf-8')
# Out:
#                                             job_title  \
# 1                                 Front End Developer
# 2                Front-end Web Developer (E-Commerce)
# 3                    Transportation Designer/Engineer
# 4   Frontend Software Developer (Javascript / Embe...
# 5                                    ServiceNow Admin
# 6                           Web / Front End Developer
# 7       Junior Back-End Development Position (remote)
# 8                                 Front-End Developer
# 9                                 Front End Developer
# 10                           Full Stack Web Developer
# 11                          Junior Developer - Sheprd
# 12                           Full Stack Web Developer
# 13                                Front-end Developer
# 14                      Lead Full Stack Web Developer
# 15                               Senior Web Developer
# 16                                Front End Developer
# 17               Front-end Web Developer (E-Commerce)
# 18                   Transportation Designer/Engineer
# 19  Frontend Software Developer (Javascript / Embe...
# 20                                   ServiceNow Admin
# 21                          Web / Front End Developer
# 22      Junior Back-End Development Position (remote)
# 23                                Front-End Developer
# 24                                Front End Developer
# 25                           Full Stack Web Developer
# 26                          Junior Developer - Sheprd
# 27                           Full Stack Web Developer
# 28                                Front-end Developer
# 29                      Lead Full Stack Web Developer
# 30                               Senior Web Developer
# 31                                Front End Developer
# 32               Front-end Web Developer (E-Commerce)
# 33                   Transportation Designer/Engineer
# 34  Frontend Software Developer (Javascript / Embe...
# 35                                   ServiceNow Admin
# 36                          Web / Front End Developer
# 37      Junior Back-End Development Position (remote)
# 38                                Front-End Developer
# 39                                Front End Developer
# 40                           Full Stack Web Developer
# 41                          Junior Developer - Sheprd
# 42                           Full Stack Web Developer
# 43                                Front-end Developer
# 44                      Lead Full Stack Web Developer
# 45                               Senior Web Developer
#
#                      company_name  \
# 1                       RWS Group
# 2         Digital Management, LLC
# 3        Nitsch Engineering, Inc.
# 4                        Humanyze
# 5                   Netpro System
# 6   FEN Learning / StoryArc Media
# 7            Kuvio Creative, LLC.
# 8                Coresecure, Inc.
# 9                  Abt Associates
# 10                         Boston
# 11              InMotion Ventures
# 12                         Artaic
# 13                       CareDash
# 14                 Liberty Mutual
# 15                    Pluralsight
# 16                      RWS Group
# 17        Digital Management, LLC
# 18       Nitsch Engineering, Inc.
# 19                       Humanyze
# 20                  Netpro System
# 21  FEN Learning / StoryArc Media
# 22           Kuvio Creative, LLC.
# 23               Coresecure, Inc.
# 24                 Abt Associates
# 25                         Boston
# 26              InMotion Ventures
# 27                         Artaic
# 28                       CareDash
# 29                 Liberty Mutual
# 30                    Pluralsight
# 31                      RWS Group
# 32        Digital Management, LLC
# 33       Nitsch Engineering, Inc.
# 34                       Humanyze
# 35                  Netpro System
# 36  FEN Learning / StoryArc Media
# 37           Kuvio Creative, LLC.
# 38               Coresecure, Inc.
# 39                 Abt Associates
# 40                         Boston
# 41              InMotion Ventures
# 42                         Artaic
# 43                       CareDash
# 44                 Liberty Mutual
# 45                    Pluralsight
#
#                                         location         salary
# 1                                     Boston, MA  Nothing_found
# 2                                 Burlington, MA  Nothing_found
# 3                               Boston, MA 02108  Nothing_found
# 4   Boston, MA 02108 (Back Bay-Beacon Hill area)  Nothing_found
# 5                                     Boston, MA  Nothing_found
# 6                                     Boston, MA  Nothing_found
# 7                                     Boston, MA  Nothing_found
# 8      Cambridge, MA 02142 (East Cambridge area)  Nothing_found
# 9      Cambridge, MA 02138 (West Cambridge area)  Nothing_found
# 10               Boston, MA 02113 (Central area)  Nothing_found
# 11                                    Boston, MA  Nothing_found
# 12                                    Boston, MA  Nothing_found
# 13                                 Cambridge, MA  Nothing_found
# 14                                    Boston, MA  Nothing_found
# 15                                    Boston, MA  Nothing_found
# 16                                    Boston, MA  Nothing_found
# 17                                Burlington, MA  Nothing_found
# 18                              Boston, MA 02108  Nothing_found
# 19  Boston, MA 02108 (Back Bay-Beacon Hill area)  Nothing_found
# 20                                    Boston, MA  Nothing_found
# 21                                    Boston, MA  Nothing_found
# 22                                    Boston, MA  Nothing_found
# 23     Cambridge, MA 02142 (East Cambridge area)  Nothing_found
# 24     Cambridge, MA 02138 (West Cambridge area)  Nothing_found
# 25               Boston, MA 02113 (Central area)  Nothing_found
# 26                                    Boston, MA  Nothing_found
# 27                                    Boston, MA  Nothing_found
# 28                                 Cambridge, MA  Nothing_found
# 29                                    Boston, MA  Nothing_found
# 30                                    Boston, MA  Nothing_found
# 31                                    Boston, MA  Nothing_found
# 32                                Burlington, MA  Nothing_found
# 33                              Boston, MA 02108  Nothing_found
# 34  Boston, MA 02108 (Back Bay-Beacon Hill area)  Nothing_found
# 35                                    Boston, MA  Nothing_found
# 36                                    Boston, MA  Nothing_found
# 37                                    Boston, MA  Nothing_found
# 38     Cambridge, MA 02142 (East Cambridge area)  Nothing_found
# 39     Cambridge, MA 02138 (West Cambridge area)  Nothing_found
# 40               Boston, MA 02113 (Central area)  Nothing_found
# 41                                    Boston, MA  Nothing_found
# 42                                    Boston, MA  Nothing_found
# 43                                 Cambridge, MA  Nothing_found
# 44                                    Boston, MA  Nothing_found
# 45                                    Boston, MA  Nothing_found
